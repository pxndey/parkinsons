# %%
import os
import numpy as np
from PIL import Image
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from tensorflow.keras.applications import ResNet152,ResNet50,VGG19,InceptionV3,MobileNetV3Large
from tensorflow.keras.layers import Dense, GlobalAveragePooling2D
from tensorflow.keras.models import Model
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.optimizers import Adam
import tensorflow as tf
from sklearn.metrics import confusion_matrix,ConfusionMatrixDisplay,accuracy_score,f1_score,precision_score,recall_score,roc_auc_score
from sklearn.metrics.pairwise import cosine_similarity
from sklearn.model_selection import train_test_split

# %%
def load_images_from_folder(base_path,subpath):
    datasets = {'healthy': {'images': [], 'labels': []},
                'parkinson': {'images': [], 'labels': []}}
    
    for dataset in ['testing', 'training']:
        dataset_path = os.path.join(base_path, subpath, dataset)
        
        for class_label, class_folder in enumerate(['healthy', 'parkinson']):
            class_path = os.path.join(dataset_path, class_folder)
            
            if os.path.isdir(class_path):
                for filename in os.listdir(class_path):
                    img_path = os.path.join(class_path, filename)
                    
                    try:
                        with Image.open(img_path) as img:
                            img = img.convert('RGB')
                            img = img.resize((224, 224))  # Adjust size as needed
                            img_array = np.array(img)
                            datasets[class_folder]['images'].append(img_array)
                            datasets[class_folder]['labels'].append(class_label)
                    except Exception as e:
                        print(f"Error loading image {img_path}: {e}")
    
    # Convert lists to numpy arrays
    for dataset in datasets:
        datasets[dataset]['images'] = np.array(datasets[dataset]['images'])
        datasets[dataset]['labels'] = np.array(datasets[dataset]['labels'])
    
    return datasets

# %%
# Usage
base_path = 'D:\Projects\Parkinsons_disease\image_model_v2\data'
datasets_spiral = load_images_from_folder(base_path,'spiral')

# Access healthy and parkinson data separately
X_healthy_spiral, y_healthy_spiral = datasets_spiral['healthy']['images'], datasets_spiral['healthy']['labels']
X_parkinson_spiral, y_parkinson_spiral = datasets_spiral['parkinson']['images'], datasets_spiral['parkinson']['labels']

print(f"Loaded {len(X_healthy_spiral)} healthy images and {len(X_parkinson_spiral)} parkinson images of spiral")
print(f"Image shape: {X_healthy_spiral[0].shape}")
print(f"Number of classes: {len(np.unique(np.concatenate([y_healthy_spiral, y_parkinson_spiral])))}")
# Out:
# Loaded 51 healthy images and 51 parkinson images of spiral
# Image shape: (224, 224, 3)
# Number of classes: 2

# %%
X = np.concatenate([X_healthy_spiral,X_parkinson_spiral],axis=0)
y = np.concatenate([y_healthy_spiral,y_parkinson_spiral],axis=0)
print(f"{X.shape},{y.shape}")
# Out:
# (102, 224, 224, 3),(102,)

# %%
x_train,x_test,y_train,y_test = train_test_split(X,y,test_size=0.2,random_state=0)
x_train,x_val,y_train,y_val = train_test_split(x_train,y_train,test_size=0.1,random_state=0)

# %%
print(f"train shape : {x_train.shape},{y_train.shape}")
print(f"val shape   : {x_val.shape},{y_val.shape}")
print(f"test shape  : {x_test.shape},{y_test.shape}")
# Out:
# train shape : (72, 224, 224, 3),(72,)
# val shape   : (9, 224, 224, 3),(9,)
# test shape  : (21, 224, 224, 3),(21,)

# %% [markdown]
# # ResNet152

# %%
base_model = ResNet152(weights='imagenet',include_top=False)
x = base_model.output
x = GlobalAveragePooling2D()(x)  # Pooling layer to reduce spatial dimensions
x = Dense(1024, activation='relu')(x)  # Dense layer for feature extraction
predictions = Dense(1, activation='softmax')(x)  # Output layer

resnet152_model = Model(inputs=base_model.input, outputs=predictions)
early_stopping = EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True)
for layer in base_model.layers:
    layer.trainable = False
    
early_stopping = EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True)
resnet152_model.compile(optimizer=Adam(learning_rate=0.0001), loss='binary_crossentropy', metrics=['accuracy'])

# %%
history = resnet152_model.fit(x_train,y_train,epochs=100,batch_size=12,validation_data=(x_val,y_val),callbacks=[early_stopping])
# Out:
# Epoch 1/100
# 6/6 [==============================] -
# 6/6 [==============================] - 3s 437ms/step - loss: 0.0348 - accuracy: 0.4861 - val_loss: 0.1140 - val_accuracy: 0.6667
# Epoch 63/100
# 6/6 [==============================] - 3s 445ms/step - loss: 0.0316 - accuracy: 0.4861 - val_loss: 0.1430 - val_accuracy: 0.6667
# Epoch 64/100
# 6/6 [==============================] - 3s 444ms/step - loss: 0.0311 - accuracy: 0.4861 - val_loss: 0.1374 - val_accuracy: 0.6667
# Epoch 65/100
# 6/6 [==============================] - 3s 446ms/step - loss: 0.0299 - accuracy: 0.4861 - val_loss: 0.1188 - val_accuracy: 0.6667
# Epoch 66/100
# 6/6 [==============================] - 3s 446ms/step - loss: 0.0296 - accuracy: 0.4861 - val_loss: 0.1378 - val_accuracy: 0.6667
# Epoch 67/100
# 6/6 [==============================] - 3s 441ms/step - loss: 0.0286 - accuracy: 0.4861 - val_loss: 0.1252 - val_accuracy: 0.6667
# Epoch 68/100
# 6/6 [==============================] - 3s 446ms/step - loss: 0.0272 - accuracy: 0.4861 - val_loss: 0.1276 - val_accuracy: 0.6667
# Epoch 69/100
# 6/6 [==============================] - 3s 464ms/step - loss: 0.0275 - accuracy: 0.4861 - val_loss: 0.1404 - val_accuracy: 0.6667

# %%
# Plot training & validation accuracy
plt.plot(history.history['accuracy'], label='Train Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.title('Model Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()
plt.show()

# %%
# Plot training & validation accuracy
plt.plot(history.history['loss'], label='Train Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.title('Model Loss')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()
plt.show()

# %% [markdown]
# # VGG19

# %%
base_model = VGG19(weights='imagenet',include_top=False)
x = base_model.output
x = GlobalAveragePooling2D()(x)  # Pooling layer to reduce spatial dimensions
x = Dense(1024, activation='relu')(x)  # Dense layer for feature extraction
predictions = Dense(1, activation='softmax')(x)  # Output layer

vgg_model = Model(inputs=base_model.input, outputs=predictions)
early_stopping = EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True)

for layer in base_model.layers:
    layer.trainable = False

vgg_model.compile(optimizer=Adam(learning_rate=0.0001), loss='binary_crossentropy', metrics=['accuracy'])
early_stopping = EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True)

# %%
history = vgg_model.fit(x_train,y_train,epochs=100,batch_size=12,validation_data=(x_val,y_val),callbacks=[early_stopping])
# Out:
# Epoch 1/100
# 6/6 [==============================] - 10s 2s/step - loss: 0.8376 - accuracy: 0.4861 - val_loss: 1.1397 - val_accuracy: 0.6667
# Epoch 2/100
# 6/6 [==============================] - 8s 1s/step - loss: 0.7304 - accuracy: 0.4861 - val_loss: 0.4365 - val_accuracy: 0.6667
# Epoch 3/100
# 6/6 [==============================] - 8s 1s/step - loss: 0.4189 - accuracy: 0.4861 - val_loss: 0.3741 - val_accuracy: 0.6667
# Epoch 4/100
# 6/6 [==============================] - 8s 1s/step - loss: 0.3184 - accuracy: 0.4861 - val_loss: 0.3471 - val_accuracy: 0.6667
# Epoch 5/100
# 6/6 [==============================] - 8s 1s/step - loss: 0.3093 - accuracy: 0.4861 - val_loss: 0.3280 - val_accuracy: 0.6667
# Epoch 6/100
# 6/6 [==============================] - 7s 1s/step - loss: 0.2766 - accuracy: 0.4861 - val_loss: 0.2851 - val_accuracy: 0.6667
# Epoch 7/100
# 6/6 [==============================] - 8s 1s/step - loss: 0.2314 - accuracy: 0.4861 - val_loss: 0.2761 - val_accuracy: 0.6667
# Epoch 8/100
# 6/6 [==============================] - 7s 1s/step - loss: 0.2202 - accuracy: 0.4861 - val_loss: 0.2786 - val_accuracy: 0.6667
# Epoch 9/100
# 6/6 [==============================] - 8s 1s/step - loss: 0.1811 - accuracy: 0.4861 - val_loss: 0.2319 - val_accuracy: 0.6667
# Epoch 10/100
# 6/6 [==============================] - 7s 1s/step - loss: 0.1700 - accuracy: 0.4861 - val_loss: 0.2221 - val_accuracy: 0.6667
# Epoch 11/100
# 6/6 [==============================] - 7s 1s/step - loss: 0.1443 - accuracy: 0.4861 - val_loss: 0.2303 - val_accuracy: 0.6667
# Epoch 12/100
# 6/6 [==============================] - 7s 1s/step - loss: 0.1405 - accuracy: 0.4861 - val_loss: 0.2304 - val_accuracy: 0.6667
# Epoch 13/100
# 6/6 [==============================] - 7s 1s/step - loss: 0.1240 - accuracy: 0.4861 - val_loss: 0.1986 - val_accuracy: 0.6667
# Epoch 14/100
# 6/6 [==============================] - 7s 1s/step - loss: 0.1158 - accuracy: 0.4861 - val_loss: 0.1913 - val_accuracy: 0.6667
# Epoch 15/100
# 6/6 [==============================] - 7s 1s/step - loss: 0.1063 - accuracy: 0.4861 - val_loss: 0.2019 - val_accuracy: 0.6667
# Epoch 16/100
# 6/6 [==============================] - 7s 1s/step - loss: 0.1020 - accuracy: 0.4861 - val_loss: 0.2056 - val_accuracy: 0.6667
# Epoch 17/100
# 6/6 [==============================] - 7s 1s/step - loss: 0.0939 - accuracy: 0.4861 - val_loss: 0.1780 - val_accuracy: 0.6667
# Epoch 18/100
# 6/6 [==============================] - 7s 1s/step - loss: 0.0896 - accuracy: 0.4861 - val_loss: 0.1865 - val_accuracy: 0.6667
# Epoch 19/100
# 6/6 [==============================] - 7s 1s/step - loss: 0.0819 - accuracy: 0.4861 - val_loss: 0.1897 - val_accuracy: 0.6667
# Epoch 20/100
# 6/6 [==============================] - 8s 1s/step - loss: 0.0772 - accuracy: 0.4861 - val_loss: 0.1945 - val_accuracy: 0.6667
# Epoch 21/100
# 6/6 [==============================] - 9s 2s/step - loss: 0.0732 - accuracy: 0.4861 - val_loss: 0.1770 - val_accuracy: 0.6667
# Epoch 22/100
# 6/6 [==============================] - 9s 1s/step - loss: 0.0690 - accuracy: 0.4861 - val_loss: 0.1856 - val_accuracy: 0.6667
# Epoch 23/100
# 6/6 [==============================] - 9s 1s/step - loss: 0.0656 - accuracy: 0.4861 - val_loss: 0.1851 - val_accuracy: 0.6667
# Epoch 24/100
# 6/6 [==============================] - 9s 2s/step - loss: 0.0618 - accuracy: 0.4861 - val_loss: 0.1751 - val_accuracy: 0.6667
# Epoch 25/100
# 6/6 [==============================] - 8s 1s/step - loss: 0.0608 - accuracy: 0.4861 - val_loss: 0.1650 - val_accuracy: 0.6667
# Epoch 26/100
# 6/6 [==============================] - 8s 1s/step - loss: 0.0545 - accuracy: 0.4861 - val_loss: 0.1867 - val_accuracy: 0.6667
# Epoch 27/100
# 6/6 [==============================] - 8s 1s/step - loss: 0.0531 - accuracy: 0.4861 - val_loss: 0.1895 - val_accuracy: 0.6667
# Epoch 28/100
# 6/6 [==============================] - 8s 1s/step - loss: 0.0504 - accuracy: 0.4861 - val_loss: 0.1780 - val_accuracy: 0.6667
# Epoch 29/100
# 6/6 [==============================] - 9s 2s/step - loss: 0.0476 - accuracy: 0.4861 - val_loss: 0.1727 - val_accuracy: 0.6667
# Epoch 30/100
# 6/6 [==============================] - 9s 2s/step - loss: 0.0458 - accuracy: 0.4861 - val_loss: 0.1752 - val_accuracy: 0.6667
# Epoch 31/100
# 6/6 [==============================] - 8s 1s/step - loss: 0.0451 - accuracy: 0.4861 - val_loss: 0.1724 - val_accuracy: 0.6667
# Epoch 32/100
# 6/6 [==============================] - 8s 1s/step - loss: 0.0421 - accuracy: 0.4861 - val_loss: 0.1893 - val_accuracy: 0.6667
# Epoch 33/100
# 6/6 [==============================] - 8s 1s/step - loss: 0.0403 - accuracy: 0.4861 - val_loss: 0.1808 - val_accuracy: 0.6667
# Epoch 34/100
# 6/6 [==============================] - 9s 2s/step - loss: 0.0387 - accuracy: 0.4861 - val_loss: 0.1715 - val_accuracy: 0.6667
# Epoch 35/100
# 6/6 [==============================] - 8s 1s/step - loss: 0.0373 - accuracy: 0.4861 - val_loss: 0.1812 - val_accuracy: 0.6667

# %%
# Plot training & validation accuracy
plt.plot(history.history['accuracy'], label='Train Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.title('Model Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()
plt.show()

# %%
# Plot training & validation accuracy
plt.plot(history.history['loss'], label='Train Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.title('Model Loss')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()
plt.show()

# %% [markdown]
# # InceptionNet

# %%
base_model = VGG19(weights='imagenet',include_top=False)
x = base_model.output
x = GlobalAveragePooling2D()(x)  # Pooling layer to reduce spatial dimensions
x = Dense(1024, activation='relu')(x)  # Dense layer for feature extraction
predictions = Dense(1, activation='softmax')(x)  # Output layer

inception_model = Model(inputs=base_model.input, outputs=predictions)
early_stopping = EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True)

for layer in base_model.layers:
    layer.trainable = False

inception_model.compile(optimizer=Adam(learning_rate=0.0001), loss='binary_crossentropy', metrics=['accuracy'])
early_stopping = EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True)

# %%
history = inception_model.fit(x_train,y_train,epochs=100,batch_size=12,validation_data=(x_val,y_val),callbacks=[early_stopping])
# Out:
# Epoch 1/100
# 6/6 [==============================] - 10s 2s/step - loss: 1.0176 - accuracy: 0.4861 - val_loss: 0.8482 - val_accuracy: 0.6667
# Epoch 2/100
# 6/6 [==============================] - 8s 1s/step - loss: 0.6060 - accuracy: 0.4861 - val_loss: 0.4186 - val_accuracy: 0.6667
# Epoch 3/100
# 6/6 [==============================] - 8s 1s/step - loss: 0.5135 - accuracy: 0.4861 - val_loss: 0.4295 - val_accuracy: 0.6667
# Epoch 4/100
# 6/6 [==============================] - 8s 1s/step - loss: 0.4124 - accuracy: 0.4861 - val_loss: 0.3832 - val_accuracy: 0.6667
# Epoch 5/100
# 6/6 [==============================] - 8s 1s/step - loss: 0.3540 - accuracy: 0.4861 - val_loss: 0.3381 - val_accuracy: 0.6667
# Epoch 6/100
# 6/6 [==============================] - 8s 1s/step - loss: 0.3278 - accuracy: 0.4861 - val_loss: 0.3246 - val_accuracy: 0.6667
# Epoch 7/100
# 6/6 [==============================] - 8s 1s/step - loss: 0.2858 - accuracy: 0.4861 - val_loss: 0.3345 - val_accuracy: 0.6667
# Epoch 8/100
# 6/6 [==============================] - 8s 1s/step - loss: 0.2580 - accuracy: 0.4861 - val_loss: 0.3150 - val_accuracy: 0.6667
# Epoch 9/100
# 6/6 [==============================] - 8s 1s/step - loss: 0.2280 - accuracy: 0.4861 - val_loss: 0.3002 - val_accuracy: 0.6667
# Epoch 10/100
# 6/6 [==============================] - 8s 1s/step - loss: 0.2037 - accuracy: 0.4861 - val_loss: 0.2850 - val_accuracy: 0.6667
# Epoch 11/100
# 6/6 [==============================] - 8s 1s/step - loss: 0.1852 - accuracy: 0.4861 - val_loss: 0.2864 - val_accuracy: 0.6667
# Epoch 12/100
# 6/6 [==============================] - 9s 1s/step - loss: 0.1672 - accuracy: 0.4861 - val_loss: 0.2862 - val_accuracy: 0.6667
# Epoch 13/100
# 6/6 [==============================] - 9s 1s/step - loss: 0.1527 - accuracy: 0.4861 - val_loss: 0.2647 - val_accuracy: 0.6667
# Epoch 14/100
# 6/6 [==============================] - 9s 2s/step - loss: 0.1430 - accuracy: 0.4861 - val_loss: 0.2677 - val_accuracy: 0.6667
# Epoch 15/100
# 6/6 [==============================] - 9s 1s/step - loss: 0.1412 - accuracy: 0.4861 - val_loss: 0.2972 - val_accuracy: 0.6667
# Epoch 16/100
# 6/6 [==============================] - 9s 2s/step - loss: 0.1202 - accuracy: 0.4861 - val_loss: 0.2492 - val_accuracy: 0.6667
# Epoch 17/100
# 6/6 [==============================] - 9s 2s/step - loss: 0.1160 - accuracy: 0.4861 - val_loss: 0.2577 - val_accuracy: 0.6667
# Epoch 18/100
# 6/6 [==============================] - 8s 1s/step - loss: 0.1172 - accuracy: 0.4861 - val_loss: 0.2987 - val_accuracy: 0.6667
# Epoch 19/100
# 6/6 [==============================] - 8s 1s/step - loss: 0.1024 - accuracy: 0.4861 - val_loss: 0.2292 - val_accuracy: 0.6667
# Epoch 20/100
# 6/6 [==============================] - 8s 1s/step - loss: 0.0924 - accuracy: 0.4861 - val_loss: 0.2523 - val_accuracy: 0.6667
# Epoch 21/100
# 6/6 [==============================] - 8s 1s/step - loss: 0.0799 - accuracy: 0.4861 - val_loss: 0.2784 - val_accuracy: 0.6667
# Epoch 22/100
# 6/6 [==============================] - 8s 1s/step - loss: 0.0819 - accuracy: 0.4861 - val_loss: 0.2553 - val_accuracy: 0.6667
# Epoch 23/100
# 6/6 [==============================] - 9s 1s/step - loss: 0.0725 - accuracy: 0.4861 - val_loss: 0.2494 - val_accuracy: 0.6667
# Epoch 24/100
# 6/6 [==============================] - 9s 1s/step - loss: 0.0678 - accuracy: 0.4861 - val_loss: 0.2429 - val_accuracy: 0.6667
# Epoch 25/100
# 6/6 [==============================] - 9s 2s/step - loss: 0.0634 - accuracy: 0.4861 - val_loss: 0.2519 - val_accuracy: 0.6667
# Epoch 26/100
# 6/6 [==============================] - 9s 1s/step - loss: 0.0603 - accuracy: 0.4861 - val_loss: 0.2435 - val_accuracy: 0.6667
# Epoch 27/100
# 6/6 [==============================] - 8s 1s/step - loss: 0.0567 - accuracy: 0.4861 - val_loss: 0.2474 - val_accuracy: 0.6667
# Epoch 28/100
# 6/6 [==============================] - 8s 1s/step - loss: 0.0544 - accuracy: 0.4861 - val_loss: 0.2434 - val_accuracy: 0.6667
# Epoch 29/100
# 6/6 [==============================] - 8s 1s/step - loss: 0.0518 - accuracy: 0.4861 - val_loss: 0.2314 - val_accuracy: 0.6667

# %%
# Plot training & validation accuracy
plt.plot(history.history['accuracy'], label='Train Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.title('Model Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()
plt.show()

# %%
# Plot training & validation accuracy
plt.plot(history.history['loss'], label='Train Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.title('Model Loss')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()
plt.show()

# %% [markdown]
# # MobileNet V3

# %%
base_model = MobileNetV3Large(weights='imagenet',include_top=False)
x = base_model.output
x = GlobalAveragePooling2D()(x)  # Pooling layer to reduce spatial dimensions
x = Dense(1024, activation='relu')(x)  # Dense layer for feature extraction
predictions = Dense(1, activation='sigmoid')(x)  # Output layer

mobilenet_model = Model(inputs=base_model.input, outputs=predictions)

for layer in base_model.layers:
    layer.trainable = False

early_stopping = EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True)
- accuracy: 1.0000 - val_loss: 0.2106 - val_accuracy: 0.8889
# Epoch 43/100
# 6/6 [==============================] - 1s 123ms/step - loss: 0.1029 - accuracy: 1.0000 - val_loss: 0.2081 - val_accuracy: 0.8889
# Epoch 44/100
# 6/6 [==============================] - 1s 113ms/step - loss: 0.0986 - accuracy: 1.0000 - val_loss: 0.2193 - val_accuracy: 0.8889
# Epoch 45/100
# 6/6 [==============================] - 1s 113ms/step - loss: 0.0970 - accuracy: 1.0000 - val_loss: 0.2087 - val_accuracy: 0.8889
# Epoch 46/100
# 6/6 [==============================] - 1s 116ms/step - loss: 0.0925 - accuracy: 1.0000 - val_loss: 0.2136 - val_accuracy: 0.8889
# Epoch 47/100
# 6/6 [==============================] - 1s 122ms/step - loss: 0.0899 - accuracy: 1.0000 - val_loss: 0.2136 - val_accuracy: 0.8889
# Epoch 48/100
# 6/6 [==============================] - 1s 126ms/step - loss: 0.0875 - accuracy: 1.0000 - val_loss: 0.2005 - val_accuracy: 0.8889
# Epoch 49/100
# 6/6 [==============================] - 1s 121ms/step - loss: 0.0851 - accuracy: 1.0000 - val_loss: 0.2002 - val_accuracy: 0.8889
# Epoch 50/100
# 6/6 [==============================] - 1s 116ms/step - loss: 0.0832 - accuracy: 1.0000 - val_loss: 0.2090 - val_accuracy: 0.8889
# Epoch 51/100
# 6/6 [==============================] - 1s 125ms/step - loss: 0.0807 - accuracy: 1.0000 - val_loss: 0.2002 - val_accuracy: 0.8889
# Epoch 52/100
# 6/6 [==============================] - 1s 125ms/step - loss: 0.0785 - accuracy: 1.0000 - val_loss: 0.1957 - val_accuracy: 0.8889
# Epoch 53/100
# 6/6 [==============================] - 1s 113ms/step - loss: 0.0758 - accuracy: 1.0000 - val_loss: 0.2011 - val_accuracy: 0.8889
# Epoch 54/100
# 6/6 [==============================] - 1s 122ms/step - loss: 0.0738 - accuracy: 1.0000 - val_loss: 0.2049 - val_accuracy: 0.8889
# Epoch 55/100
# 6/6 [==============================] - 1s 125ms/step - loss: 0.0723 - accuracy: 1.0000 - val_loss: 0.2000 - val_accuracy: 0.8889
# Epoch 56/100
# 6/6 [==============================] - 1s 120ms/step - loss: 0.0701 - accuracy: 1.0000 - val_loss: 0.1905 - val_accuracy: 0.8889
# Epoch 57/100
# 6/6 [==============================] - 1s 116ms/step - loss: 0.0684 - accuracy: 1.0000 - val_loss: 0.1947 - val_accuracy: 0.8889
# Epoch 58/100
# 6/6 [==============================] - 1s 116ms/step - loss: 0.0664 - accuracy: 1.0000 - val_loss: 0.1950 - val_accuracy: 0.8889
# Epoch 59/100
# 6/6 [==============================] - 1s 131ms/step - loss: 0.0652 - accuracy: 1.0000 - val_loss: 0.1871 - val_accuracy: 0.8889
# Epoch 60/100
# 6/6 [==============================] - 1s 127ms/step - loss: 0.0639 - accuracy: 1.0000 - val_loss: 0.1833 - val_accuracy: 0.8889
# Epoch 61/100
# 6/6 [==============================] - 1s 119ms/step - loss: 0.0621 - accuracy: 1.0000 - val_loss: 0.1979 - val_accuracy: 0.8889
# Epoch 62/100
# 6/6 [==============================] - 1s 116ms/step - loss: 0.0627 - accuracy: 1.0000 - val_loss: 0.2017 - val_accuracy: 0.8889
# Epoch 63/100
# 6/6 [==============================] - 1s 157ms/step - loss: 0.0600 - accuracy: 1.0000 - val_loss: 0.1730 - val_accuracy: 0.8889
# Epoch 64/100
# 6/6 [==============================] - 1s 153ms/step - loss: 0.0582 - accuracy: 1.0000 - val_loss: 0.1756 - val_accuracy: 0.8889
# Epoch 65/100
# 6/6 [==============================] - 1s 125ms/step - loss: 0.0558 - accuracy: 1.0000 - val_loss: 0.1966 - val_accuracy: 0.8889
# Epoch 66/100
# 6/6 [==============================] - 1s 120ms/step - loss: 0.0546 - accuracy: 1.0000 - val_loss: 0.1973 - val_accuracy: 0.8889
# Epoch 67/100
# 6/6 [==============================] - 1s 116ms/step - loss: 0.0525 - accuracy: 1.0000 - val_loss: 0.1797 - val_accuracy: 0.8889
# Epoch 68/100
# 6/6 [==============================] - 1s 119ms/step - loss: 0.0515 - accuracy: 1.0000 - val_loss: 0.1750 - val_accuracy: 0.8889
# Epoch 69/100
# 6/6 [==============================] - 1s 119ms/step - loss: 0.0508 - accuracy: 1.0000 - val_loss: 0.1878 - val_accuracy: 0.8889
# Epoch 70/100
# 6/6 [==============================] - 1s 131ms/step - loss: 0.0489 - accuracy: 1.0000 - val_loss: 0.1840 - val_accuracy: 0.8889
# Epoch 71/100
# 6/6 [==============================] - 1s 136ms/step - loss: 0.0478 - accuracy: 1.0000 - val_loss: 0.1725 - val_accuracy: 0.8889
# Epoch 72/100
# 6/6 [==============================] - 1s 132ms/step - loss: 0.0467 - accuracy: 1.0000 - val_loss: 0.1759 - val_accuracy: 0.8889
# Epoch 73/100
# 6/6 [==============================] - 1s 118ms/step - loss: 0.0458 - accuracy: 1.0000 - val_loss: 0.1890 - val_accuracy: 0.8889
# Epoch 74/100
# 6/6 [==============================] - 1s 126ms/step - loss: 0.0443 - accuracy: 1.0000 - val_loss: 0.1845 - val_accuracy: 0.8889
# Epoch 75/100
# 6/6 [==============================] - 1s 123ms/step - loss: 0.0446 - accuracy: 1.0000 - val_loss: 0.1661 - val_accuracy: 0.8889
# Epoch 76/100
# 6/6 [==============================] - 1s 119ms/step - loss: 0.0422 - accuracy: 1.0000 - val_loss: 0.1733 - val_accuracy: 0.8889
# Epoch 77/100
# 6/6 [==============================] - 1s 116ms/step - loss: 0.0409 - accuracy: 1.0000 - val_loss: 0.1824 - val_accuracy: 0.8889
# Epoch 78/100
# 6/6 [==============================] - 1s 117ms/step - loss: 0.0403 - accuracy: 1.0000 - val_loss: 0.1791 - val_accuracy: 0.8889
# Epoch 79/100
# 6/6 [==============================] - 1s 116ms/step - loss: 0.0393 - accuracy: 1.0000 - val_loss: 0.1800 - val_accuracy: 0.8889
# Epoch 80/100
# 6/6 [==============================] - 1s 120ms/step - loss: 0.0381 - accuracy: 1.0000 - val_loss: 0.1738 - val_accuracy: 0.8889
# Epoch 81/100
# 6/6 [==============================] - 1s 120ms/step - loss: 0.0374 - accuracy: 1.0000 - val_loss: 0.1693 - val_accuracy: 0.8889
# Epoch 82/100
# 6/6 [==============================] - 1s 125ms/step - loss: 0.0367 - accuracy: 1.0000 - val_loss: 0.1692 - val_accuracy: 0.8889
# Epoch 83/100
# 6/6 [==============================] - 1s 123ms/step - loss: 0.0374 - accuracy: 1.0000 - val_loss: 0.1873 - val_accuracy: 0.8889
# Epoch 84/100
# 6/6 [==============================] - 1s 134ms/step - loss: 0.0360 - accuracy: 1.0000 - val_loss: 0.1652 - val_accuracy: 0.8889
# Epoch 85/100
# 6/6 [==============================] - 1s 127ms/step - loss: 0.0341 - accuracy: 1.0000 - val_loss: 0.1682 - val_accuracy: 0.8889
# Epoch 86/100
# 6/6 [==============================] - 1s 119ms/step - loss: 0.0333 - accuracy: 1.0000 - val_loss: 0.1726 - val_accuracy: 0.8889
# Epoch 87/100
# 6/6 [==============================] - 1s 128ms/step - loss: 0.0326 - accuracy: 1.0000 - val_loss: 0.1722 - val_accuracy: 0.8889
# Epoch 88/100
# 6/6 [==============================] - 1s 137ms/step - loss: 0.0320 - accuracy: 1.0000 - val_loss: 0.1733 - val_accuracy: 0.8889
# Epoch 89/100
# 6/6 [==============================] - 1s 133ms/step - loss: 0.0311 - accuracy: 1.0000 - val_loss: 0.1706 - val_accuracy: 0.8889
# Epoch 90/100
# 6/6 [==============================] - 1s 137ms/step - loss: 0.0309 - accuracy: 1.0000 - val_loss: 0.1638 - val_accuracy: 0.8889
# Epoch 91/100
# 6/6 [==============================] - 1s 128ms/step - loss: 0.0299 - accuracy: 1.0000 - val_loss: 0.1709 - val_accuracy: 0.8889
# Epoch 92/100
# 6/6 [==============================] - 1s 127ms/step - loss: 0.0293 - accuracy: 1.0000 - val_loss: 0.1682 - val_accuracy: 0.8889
# Epoch 93/100
# 6/6 [==============================] - 1s 115ms/step - loss: 0.0286 - accuracy: 1.0000 - val_loss: 0.1694 - val_accuracy: 0.8889
# Epoch 94/100
# 6/6 [==============================] - 1s 130ms/step - loss: 0.0281 - accuracy: 1.0000 - val_loss: 0.1725 - val_accuracy: 0.8889
# Epoch 95/100
# 6/6 [==============================] - 1s 125ms/step - loss: 0.0274 - accuracy: 1.0000 - val_loss: 0.1673 - val_accuracy: 0.8889
# Epoch 96/100
# 6/6 [==============================] - 1s 120ms/step - loss: 0.0270 - accuracy: 1.0000 - val_loss: 0.1681 - val_accuracy: 0.8889
# Epoch 97/100
# 6/6 [==============================] - 1s 120ms/step - loss: 0.0263 - accuracy: 1.0000 - val_loss: 0.1669 - val_accuracy: 0.8889
# Epoch 98/100
# 6/6 [==============================] - 1s 124ms/step - loss: 0.0258 - accuracy: 1.0000 - val_loss: 0.1649 - val_accuracy: 0.8889
# Epoch 99/100
# 6/6 [==============================] - 1s 122ms/step - loss: 0.0254 - accuracy: 1.0000 - val_loss: 0.1660 - val_accuracy: 0.8889
# Epoch 100/100
# 6/6 [==============================] - 1s 145ms/step - loss: 0.0248 - accuracy: 1.0000 - val_loss: 0.1630 - val_accuracy: 0.8889

# %%
# Plot training & validation accuracy
plt.plot(history.history['accuracy'], label='Train Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.title('Model Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()
plt.show()

# %%
# Plot training & validation accuracy
plt.plot(history.history['loss'], label='Train Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.title('Model Loss')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()
plt.show()

# %%
ypreds_resnet50 = resnet50_model.predict(x_test)
ypreds_resnet152 = resnet152_model.predict(x_test)
ypreds_mobilenet = mobilenet_model.predict(x_test)
ypreds_inception = inception_model.predict(x_test)
ypreds_vgg19 = vgg_model.predict(x_test)
# Out:
# 1/1 [==============================] - 1s 598ms/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 0s 180ms/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 2s 2s/step

# %%
ypreds_resnet50 = np.where(ypreds_resnet50>=0.5,1,0) 
ypreds_resnet152 = np.where(ypreds_resnet152>=0.5,1,0)
ypreds_mobilenet = np.where(ypreds_mobilenet>=0.5,1,0)
ypreds_inception = np.where(ypreds_inception>=0.5,1,0)
ypreds_vgg19 =np.where(ypreds_vgg19>=0.5,1,0)

# %% [markdown]
# # Metrics for Resnet50

# %%
print(f"Accuracy: {accuracy_score(y_test,ypreds_resnet50)}")
print(f"Precision: {precision_score(y_test,ypreds_resnet50)}")
print(f"Recall: {recall_score(y_test,ypreds_resnet50)}")
print(f"F1 Score: {f1_score(y_test,ypreds_resnet50)}")
print(f"ROC Score: {roc_auc_score(y_test,ypreds_resnet50)}")
# Out:
# Accuracy: 0.47619047619047616
# Precision: 0.47619047619047616
# Recall: 1.0
# F1 Score: 0.6451612903225806
# ROC Score: 0.5

# %%
ConfusionMatrixDisplay(confusion_matrix(y_test,ypreds_resnet50)).plot()

# %% [markdown]
# # Metrics for ResNet152

# %%
print(f"Accuracy: {accuracy_score(y_test,ypreds_resnet152)}")
print(f"Precision: {precision_score(y_test,ypreds_resnet152)}")
print(f"Recall: {recall_score(y_test,ypreds_resnet152)}")
print(f"F1 Score: {f1_score(y_test,ypreds_resnet152)}")
print(f"ROC Score: {roc_auc_score(y_test,ypreds_resnet152)}")
# Out:
# Accuracy: 0.47619047619047616
# Precision: 0.47619047619047616
# Recall: 1.0
# F1 Score: 0.6451612903225806
# ROC Score: 0.5

# %%
ConfusionMatrixDisplay(confusion_matrix(y_test,ypreds_resnet152)).plot()

# %% [markdown]
# # Metrics for InceptionNet

# %%
print(f"Accuracy: {accuracy_score(y_test,ypreds_inception)}")
print(f"Precision: {precision_score(y_test,ypreds_inception)}")
print(f"Recall: {recall_score(y_test,ypreds_inception)}")
print(f"F1 Score: {f1_score(y_test,ypreds_inception)}")
print(f"ROC Score: {roc_auc_score(y_test,ypreds_inception)}")
# Out:
# Accuracy: 0.47619047619047616
# Precision: 0.47619047619047616
# Recall: 1.0
# F1 Score: 0.6451612903225806
# ROC Score: 0.5

# %%
ConfusionMatrixDisplay(confusion_matrix(y_test,ypreds_inception)).plot()

# %% [markdown]
# # Metrics for VGG19

# %%
print(f"Accuracy: {accuracy_score(y_test,ypreds_vgg19)}")
print(f"Precision: {precision_score(y_test,ypreds_vgg19)}")
print(f"Recall: {recall_score(y_test,ypreds_vgg19)}")
print(f"F1 Score: {f1_score(y_test,ypreds_vgg19)}")
print(f"ROC Score: {roc_auc_score(y_test,ypreds_vgg19)}")
# Out:
# Accuracy: 0.47619047619047616
# Precision: 0.47619047619047616
# Recall: 1.0
# F1 Score: 0.6451612903225806
# ROC Score: 0.5

# %%
ConfusionMatrixDisplay(confusion_matrix(y_test,ypreds_vgg19)).plot()

# %% [markdown]
# # Metrics for MobileNet V3

# %%
print(f"Accuracy: {accuracy_score(y_test,ypreds_mobilenet)}")
print(f"Precision: {precision_score(y_test,ypreds_mobilenet)}")
print(f"Recall: {recall_score(y_test,ypreds_mobilenet)}")
print(f"F1 Score: {f1_score(y_test,ypreds_mobilenet)}")
print(f"ROC Score: {roc_auc_score(y_test,ypreds_mobilenet)}")
# Out:
# Accuracy: 0.7619047619047619
# Precision: 0.8571428571428571
# Recall: 0.6
# F1 Score: 0.7058823529411764
# ROC Score: 0.7545454545454545

# %%
ConfusionMatrixDisplay(confusion_matrix(y_test,ypreds_mobilenet)).plot()
